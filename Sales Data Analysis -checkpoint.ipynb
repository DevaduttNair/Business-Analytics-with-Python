# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Supermarket_sales.csv")
df
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
df.Unitprice
# Out:
# 0      74.69
# 1      15.28
# 2      46.33
# 3      58.22
# 4      86.31
#        ...
# 995    40.35
# 996    97.38
# 997    31.84
# 998    65.82
# 999    88.34
# Name: Unitprice, Length: 1000, dtype: float64

# %%
df['Quantity'].max()
# Out:
# 10

# %%
df['Quantity'].min()
# Out:
# 1

# %%
df['Quantity'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0       7
# 1       5
# 2       7
# 3       8
# 4       7
#        ..
# 995     1
# 996    10
# 997     1
# 998     1
# 999     7
# Name: Quantity, Length: 1000, dtype: int64>

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Quantity"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
max(new_data)
# Out:
# 10

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Quantity"])
min(new_data)
# Out:
# 1

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Quantity"])
sum(new_data)/len(new_data)
# Out:
# 12.117647058823529

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Unitprice"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
max(new_data)
# Out:
# 99.96

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Unitprice"])
min(new_data)
# Out:
# 10.08

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Health and beauty"):
        new_data.append(df.loc[x,"Unitprice"])
sum(new_data)/len(new_data)
# Out:
# 61.031895424836605

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Electronic accessories"):
        new_data.append(df.loc[x,"Quantity"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
max(new_data)
# Out:
# 10

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Electronic accessories"):
        new_data.append(df.loc[x,"Quantity"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
min(new_data)
# Out:
# 1

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Productline"] == "Electronic accessories"):
        new_data.append(df.loc[x,"Quantity"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
sum(new_data)/len(new_data)
# Out:
# 5.711764705882353

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Quantity"] == 10):
        new_data.append(df.loc[x,"Unitprice"])
new_data.remove(1000)
max(new_data)
# Out:
# 99.3

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Quantity"] == 1):
        new_data.append(df.loc[x,"Unitprice"])
new_data.remove(1000)
min(new_data)
# Out:
# 10.17

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Quantity"] == 10):
        if (df.loc[x,"Unitprice"] == 99.3):
            new_data.append(df.loc[x,"InvoiceID"])
new_data.remove(1000)
new_data
# Out:
# ['860-79-0874']

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"Quantity"] == 1):
        if (df.loc[x,"Unitprice"] == 10.17):
            new_data.append(df.loc[x,"InvoiceID"])
new_data.remove(1000)
new_data
# Out:
# ['784-21-9238']

# %%
df[(df.Productline == 'Health and beauty') & (df.Gender == "Male")]
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 3      4  123-19-1176      A     Yangon       Member   Male
# 21    22  371-85-5789      B   Mandalay       Normal   Male
# 29    30  848-62-7243      A     Yangon       Normal   Male
# 33    34  595-11-5460      A     Yangon       Normal   Male
# 44    45  617-15-4209      C  Naypyitaw       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 981  982  809-46-1866      A     Yangon       Normal   Male
# 983  984  148-41-7930      C  Naypyitaw       Normal   Male
# 987  988  552-44-5977      B   Mandalay       Member   Male
# 989  990  430-53-4718      B   Mandalay       Member   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
#
#            Productline  Unitprice  Quantity      Tax     Total       Date  \
# 3    Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 21   Health and beauty      87.98         3  13.1970  277.1370   3/5/2019
# ...

# %%
len(df[(df.Productline == 'Health and beauty') & (df.Gender == "Male")])
# Out:
# 88

# %%
df[(df.Productline == 'Fashion accessories') & (df.Gender == "Female")]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 49     50  574-22-5561      C  Naypyitaw       Member  Female
# 52     53  616-24-2851      B   Mandalay       Member  Female
# 67     68  109-28-2512      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 931   932  756-93-1854      C  Naypyitaw       Member  Female
# 955   956  846-10-0341      A     Yangon       Normal  Female
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
len(df[(df.Productline == 'Fashion accessories') & (df.Gender == "Female")])
# Out:
# 96

# %%
df[((df.Productline == 'Fashion accessories') | (df.Productline == 'Sports and travel')) & (df.Gender == "Female")]
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 10     11  351-62-0822      B   Mandalay       Member  Female
# 15     16  299-46-1805      B   Mandalay       Member  Female
# 27     28  189-17-4241      A     Yangon       Normal  Female
# 35     36  232-16-2483      C  Naypyitaw       Member  Female
# 42     43  354-25-5821      B   Mandalay       Member  Female
# ..    ...          ...    ...        ...          ...     ...
# 962   963  593-08-5916      A     Yangon       Normal  Female
# 982   983  139-32-4183      A     Yangon       Member  Female
# 985   986  374-38-5555      B   Mandalay       Normal  Female
# 991   992  602-16-6955      B   Mandalay       Normal  Female
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax     Total       Date  \
# 10   Fashion accessories      14.48         4   2.8960   60.8160   2/6/2019
# ...

# %%
len(df[((df.Productline == 'Fashion accessories') | (df.Productline == 'Sports and travel')) & (df.Gender == "Female")])
# Out:
# 184

# %%
x = df['Quantity'].to_numpy()
x
# Out:
# array([ 7,  5,  7,  8,  7,  7,  6, 10,  2,  3,  4,  4,  5, 10, 10,  6,  7,
#         6,  3,  2,  5,  3,  2,  5,  3,  8,  1,  2,  5,  9,  5,  9,  8,  2,
#         4,  1,  5,  9,  8,  8,  1,  2,  6,  8,  2,  4,  9,  9,  6, 10,  7,
#         5,  4,  1,  2,  8,  2,  8, 10,  6,  3,  6,  9, 10,  4, 10,  2,  6,
#        10,  1, 10, 10,  3,  6,  9, 10,  9,  9, 10,  5,  6,  3,  8,  4,  5,
#         7,  5,  7,  1,  6,  4, 10,  7,  9,  1,  1, 10,  6,  3,  6,  1,  9,
#         9,  6,  7, 10,  6,  6,  9, 10,  2,  3,  7,  9,  9,  3,  5,  1, 10,
#         2,  8,  7,  9,  8,  8,  7,  5,  9,  8,  9,  7,  6,  4,  6,  6,  3,
#         5,  6, 10,  8, 10, 10, 10,  1,  6,  6, 10,  4,  8,  8,  4,  7,  9,
#         6,  8,  5,  1,  5,  9,  6,  8,  1,  7,  2, 10,  8, 10, 10,  6,  7,
#         5,  5,  8,  6,  8,  9,  8,  7,  6,  3,  7,  8, 10,  8,  7,  3,  8,
#         4,  1,  4,  3,  2,  9,  4,  5,  1,  2,  1,  4,  5,  6,  4,  7, 10,
# ...

# %%
x = df.groupby('Gender')
x.first()
# Out:
#         No    InvoiceID Branch    City Customertype         Productline  \
# Gender
# Female   1  750-67-8428      A  Yangon       Member   Health and beauty
# Male     3  631-41-3108      A  Yangon       Normal  Home and lifestyle
#
#         Unitprice  Quantity      Tax     Total      Date   Time      Payment  \
# Gender
# Female      74.69         7  26.1415  548.9715  1/5/2019  13:08      Ewallet
# Male        46.33         7  16.2155  340.5255  3/3/2019  13:23  Credit card
#
#           cogs  gross_margin_percentage  gross_iincome  Rating
# Gender
# Female  522.83                 4.761905        26.1415     9.1
# Male    324.31                 4.761905        16.2155     7.4

# %%
col1=x.get_group('Male')
col1
# Out:
#       No    InvoiceID Branch       City Customertype Gender  \
# 2      3  631-41-3108      A     Yangon       Normal   Male
# 3      4  123-19-1176      A     Yangon       Member   Male
# 4      5  373-73-7910      A     Yangon       Normal   Male
# 5      6  699-14-3026      C  Naypyitaw       Normal   Male
# 11    12  529-56-3974      B   Mandalay       Member   Male
# ..   ...          ...    ...        ...          ...    ...
# 992  993  745-74-0715      A     Yangon       Normal   Male
# 993  994  690-01-6631      B   Mandalay       Normal   Male
# 995  996  233-67-5758      C  Naypyitaw       Normal   Male
# 997  998  727-02-1313      A     Yangon       Member   Male
# 998  999  347-56-2442      A     Yangon       Normal   Male
#
#                 Productline  Unitprice  Quantity      Tax     Total  \
# 2        Home and lifestyle      46.33         7  16.2155  340.5255
# 3         Health and beauty      58.22         8  23.2880  489.0480
# ...

# %%
x1=col1['Quantity'].to_numpy()
x1
# Out:
# array([ 7,  8,  7,  7,  4, 10,  6,  3,  5,  3,  2,  5,  3,  1,  9,  5,  9,
#         8,  2,  5,  8,  2,  2,  9,  6,  7,  1,  2,  2,  8,  6,  6, 10,  4,
#        10, 10, 10, 10,  9,  9,  8,  5,  5,  7,  1,  9,  1,  1, 10,  3,  6,
#         1,  9,  6,  7, 10,  6,  6, 10,  9,  5,  1,  2,  7,  9,  8,  6,  3,
#        10,  8, 10,  4,  8,  8,  7,  9,  5,  1,  5,  9,  6,  1,  7,  2, 10,
#         8, 10, 10,  6,  7,  5,  5,  8,  6,  8,  9,  8,  6,  3,  7,  8, 10,
#         8,  3,  4,  1,  4,  5,  2,  4,  7, 10,  5,  9,  5,  3,  1,  8,  6,
#         7,  5,  2,  9,  4,  4, 10,  5,  1,  9,  2,  2,  4,  8,  8,  5,  4,
#         7,  9, 10,  4,  8,  4,  1,  6,  4,  4,  1,  4,  4,  7, 10, 10,  1,
#         6,  5,  1, 10,  7, 10,  4,  6,  4,  2,  1,  1,  7,  6,  2,  2,  5,
#         4,  6,  6,  4,  5,  4,  4,  4,  9,  3,  5,  2,  5,  9,  3,  3,  1,
#         7,  7,  9,  3,  1,  8,  2,  6,  4,  9,  6,  7,  4,  4,  1,  6,  7,
# ...

# %%
y1=col1['Tax'].to_numpy()
y1
# Out:
# array([16.2155, 23.288 , 30.2085, 29.8865,  5.102 , 21.595 , 21.783 ,
#         8.2005, 21.51  , 13.197 ,  3.32  ,  8.64  , 13.2945,  1.676 ,
#        11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 15.655 , 12.048 ,
#         5.611 ,  1.537 , 25.5105,  5.679 , 31.99  ,  0.7715,  1.616 ,
#         4.434 , 35.84  ,  9.183 , 16.719 ,  7.905 , 15.148 ,  7.935 ,
#        39.385 , 44.74  , 31.06  , 33.6015, 22.068 ,  7.7   , 12.2275,
#        19.13  , 17.283 ,  2.1235, 28.962 ,  4.4875,  4.858 , 43.935 ,
#         7.9125, 24.81  ,  2.4355, 35.3475, 17.478 , 10.6225, 44.335 ,
#         8.214 , 18.639 , 40.985 , 26.1315,  5.485 ,  2.568 ,  5.344 ,
#        19.992 , 44.982 , 25.564 , 26.235 , 13.533 , 25.955 , 29.    ,
#        45.25  , 13.228 , 28.744 , 12.984 , 12.096 , 37.458 , 23.0725,
#         3.6085, 12.57  , 43.749 , 28.017 ,  3.1845, 16.0265,  7.64  ,
#        19.95  , 17.028 , 47.79  , 49.49  , 15.384 , 24.332 , 17.5025,
# ...

# %%
plt.scatter(x1,y1)
plt.plot(x1,y1)

# %%
y = df['Tax'].to_numpy()
y
# Out:
# array([26.1415,  3.82  , 16.2155, 23.288 , 30.2085, 29.8865, 20.652 ,
#        36.78  ,  3.626 ,  8.226 ,  2.896 ,  5.102 , 11.7375, 21.595 ,
#        35.69  , 28.116 , 24.1255, 21.783 ,  8.2005,  4.03  , 21.51  ,
#        13.197 ,  3.32  ,  8.64  , 13.2945, 21.036 ,  1.676 ,  8.767 ,
#        22.09  , 11.2005, 23.5325, 35.1315, 33.512 ,  9.658 , 19.884 ,
#         3.406 , 15.655 , 27.396 , 21.968 , 12.048 ,  4.336 ,  5.611 ,
#        20.736 , 39.48  ,  1.537 , 18.792 , 25.5105,  9.0045,  5.679 ,
#        41.315 , 31.99  , 11.1475,  3.574 ,  0.7715,  1.616 , 34.392 ,
#         4.434 , 35.84  , 36.175 ,  9.183 ,  3.711 , 16.719 , 24.7815,
#         7.905 , 15.148 ,  7.935 ,  3.347 , 29.283 , 39.385 ,  0.9165,
#        44.74  , 31.06  ,  7.278 , 22.773 , 33.6015, 20.825 , 22.068 ,
#         9.0045, 39.155 ,  5.095 , 29.757 , 14.502 ,  7.7   , 16.072 ,
#        12.2275, 29.071 , 19.13  , 17.283 ,  2.1235, 23.097 ,  9.476 ,
# ...

# %%
plt.plot(new_datax,new_datay)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-6a6a96e90e04> in <module>
# ----> 1 plt.plot(new_datax,new_datay)
#
# NameError: name 'new_datax' is not defined

# %%
new_data=[len(df)]
for x in df.index:
    if (df.loc[x,"City"] == "Yangon"):
        new_data.append(df.loc[x,"Tax"])
new_data.remove(1000)  #.remove is used to remove a certain value thats added in the list 
sum(new_data)
# Out:
# 5057.160500000002

# %%
x1= col1.to_numpy()
x1
# Out:
# array([[3, '631-41-3108', 'A', ..., 4.761904762, 16.2155, 7.4],
#        [4, '123-19-1176', 'A', ..., 4.761904762, 23.288, 8.4],
#        [5, '373-73-7910', 'A', ..., 4.761904762, 30.2085, 5.3],
#        ...,
#        [996, '233-67-5758', 'C', ..., 4.761904762, 2.0175, 6.2],
#        [998, '727-02-1313', 'A', ..., 4.761904762, 1.592, 7.7],
#        [999, '347-56-2442', 'A', ..., 4.761904762, 3.291, 4.1]],
#       dtype=object)

# %%
new_datax=[len(df)]
for x in df.index:
    if (df.loc[x,"Gender"] == "Male"):
        new_datax.append(df.loc[x,"Quantity"])
new_datax.remove(1000)
new_datax
# Out:
# [7,
#  8,
#  7,
#  7,
#  4,
#  10,
#  6,
#  3,
#  5,
#  3,
#  2,
#  5,
#  3,
#  1,
#  9,
#  5,
#  9,
#  8,
#  2,
#  5,
#  8,
#  2,
#  2,
#  9,
#  6,
#  7,
#  1,
#  2,
#  2,
#  8,
#  6,
#  6,
#  10,
#  4,
#  10,
#  10,
#  10,
#  10,
#  9,
#  9,
#  8,
#  5,
#  5,
#  7,
#  1,
#  9,
#  1,
#  1,
#  10,
#  3,
#  6,
#  1,
#  9,
#  6,
#  7,
#  10,
#  6,
#  6,
#  10,
#  9,
#  5,
#  1,
#  2,
#  7,
#  9,
#  8,
#  6,
#  3,
#  10,
#  8,
#  10,
#  4,
#  8,
#  8,
#  7,
#  9,
#  5,
#  1,
#  5,
#  9,
#  6,
#  1,
#  7,
#  2,
#  10,
#  8,
#  10,
#  10,
#  6,
#  7,
#  5,
#  5,
#  8,
#  6,
#  8,
#  9,
#  8,
#  6,
#  3,
#  7,
#  8,
#  10,
#  8,
#  3,
#  4,
#  1,
#  4,
#  5,
#  2,
#  4,
#  7,
#  10,
#  5,
#  9,
#  5,
#  3,
#  1,
#  8,
#  6,
#  7,
#  5,
#  2,
#  9,
#  4,
#  4,
#  10,
#  5,
#  1,
#  9,
#  2,
#  2,
#  4,
#  8,
#  8,
#  5,
#  4,
#  7,
#  9,
#  10,
#  4,
#  8,
#  4,
#  1,
#  6,
#  4,
#  4,
#  1,
#  4,
#  4,
#  7,
#  10,
#  10,
#  1,
#  6,
#  5,
#  1,
#  10,
#  7,
#  10,
#  4,
#  6,
#  4,
#  2,
# ...

# %%
new_datay=[len(df)]
for x in df.index:
    if (df.loc[x,"Gender"] == "Male"):
        new_datay.append(df.loc[x,"Tax"])
new_datay.remove(1000)
new_datay
# Out:
# [16.2155,
#  23.288,
#  30.2085,
#  29.8865,
#  5.102,
#  21.595,
#  21.783,
#  8.2005,
#  21.51,
#  13.197,
#  3.32,
#  8.64,
#  13.2945,
#  1.676,
#  11.2005,
#  23.5325,
#  35.1315,
#  33.512,
#  9.658,
#  15.655,
#  12.048,
#  5.611,
#  1.537,
#  25.5105,
#  5.679,
#  31.99,
#  0.7715,
#  1.616,
#  4.434,
#  35.84,
#  9.183,
#  16.719,
#  7.905,
#  15.148,
#  7.935,
#  39.385,
#  44.74,
#  31.06,
#  33.6015,
#  22.068,
#  7.7,
#  12.2275,
#  19.13,
#  17.283,
#  2.1235,
#  28.962,
#  4.4875,
#  4.858,
#  43.935,
#  7.9125,
#  24.81,
#  2.4355,
#  35.3475,
#  17.478,
#  10.6225,
#  44.335,
#  8.214,
#  18.639,
#  40.985,
#  26.1315,
#  5.485,
#  2.568,
#  5.344,
#  19.992,
#  44.982,
#  25.564,
#  26.235,
#  13.533,
#  25.955,
#  29.0,
#  45.25,
#  13.228,
#  28.744,
#  12.984,
#  12.096,
#  37.458,
#  23.0725,
#  3.6085,
#  12.57,
#  43.749,
#  28.017,
#  3.1845,
#  16.0265,
#  7.64,
#  19.95,
#  17.028,
#  47.79,
#  49.49,
#  15.384,
#  24.332,
#  17.5025,
#  20.0125,
#  8.34,
# ...

# %%
plt.scatter(new_datax,new_datay)
